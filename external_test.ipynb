# %%
from sklearn.metrics import r2_score,mean_squared_error
import matplotlib.pyplot as plt
from pandas import read_csv
import pandas as pd
import numpy as np
from sklearn import preprocessing

from sklearn.linear_model import LogisticRegression, Lasso
import scikitplot as skplt
import matplotlib.pyplot as plt
import joblib
from sklearn.metrics import classification_report,roc_curve, auc, plot_roc_curve
import warnings
from sklearn.metrics import confusion_matrix
from scipy import stats
import seaborn as sns
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import SelectPercentile, f_regression
from sklearn.linear_model import SGDRegressor
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline, make_union
from sklearn.preprocessing import Binarizer, Normalizer
from sklearn.svm import LinearSVR
from tpot.builtins import StackingEstimator
from tpot.export_utils import set_param_recursive

# %%
# Average CV score on the training set was: -61.53421953086297

model = joblib.load('./ahvpg.m')
df = pd.read_csv('external_test.csv')

# %%
df.shape
# Out:
# (25, 2438)

# %%
X_train=df.iloc[:,2:]
y_train=df.iloc[:,1]
y_train=y_train.round(0)

# %%
network_train = model.predict(X_train)

# %%
result_train=df.iloc[:,0:2]
result_train['Pred']=network_train 
result_train.to_csv('result_addhvpg.csv')

# %%
sns.set(context='paper',font='Aria',font_scale=1)
pal1 = sns.color_palette(['#ED0000'])
sns.set_style("ticks")
pic=sns.lmplot(x='HVPG', y='Pred', data=result_train,palette=pal1,height=8,sharey = True,sharex = False,scatter=True,fit_reg=True,ci=95,x_jitter=0.5,y_jitter=0.5)
#ax1= pic.axes[0]
#ax1.set_xticks([0, 5, 10, 12, 16, 20, 25, 30, 35, 40])

pic.savefig('HVPGADD.ai',dpi=900,format='eps')
#pic.savefig('相关.jpg',dpi=900,format='jpg')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
